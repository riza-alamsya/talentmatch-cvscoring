# %%
# ── CV Scoring (HYBRID) pakai MiMo (chat) + bge-m3 (embedding lokal) ─
# Jalankan SETELAH cv_embedding_mimo_v1 (koleksi 'cv_chunks_mimo' sudah terisi).

from openai import OpenAI
from sentence_transformers import SentenceTransformer
import json, chromadb
from pathlib import Path
from datetime import date

API_KEY     = "sk-sfoim1txpf2e6ng5eztc4e50996hbtgby6wug8hfrur87few"
BASE_URL    = "https://api.xiaomimimo.com/v1"
LLM_MODEL   = "mimo-v2.5"
EMBED_MODEL = "BAAI/bge-m3"

client   = OpenAI(api_key=API_KEY, base_url=BASE_URL)
embedder = SentenceTransformer(EMBED_MODEL)

PROCESSED_DIR = Path("../../data/processed_mimo")
CHROMA_DIR    = Path("../../data/chroma")
COLLECTION    = "cv_chunks_mimo"

chroma_client = chromadb.PersistentClient(path=str(CHROMA_DIR))
col = chroma_client.get_collection(COLLECTION)

CVS = {jf.stem: json.load(open(jf, encoding="utf-8")) for jf in sorted(PROCESSED_DIR.glob("*.json"))}
print(f"{len(CVS)} CV dimuat | {col.count()} vektor di Chroma ({COLLECTION})")

def embed_query(text: str) -> list:
    return embedder.encode(text, normalize_embeddings=True, prompt_name="query").tolist()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# 11 CV dimuat | 58 vektor di Chroma (cv_chunks_mimo)

# %%
# ── 1) Helper deterministik: skills, pengalaman, pendidikan ───────────
TODAY_YM = date.today().year * 12 + date.today().month

def candidate_skills(cv):
    s = set()
    for k in cv.get("skills", {}).get("hard_skills", []) + cv.get("skills", {}).get("soft_skills", []):
        s.add(k.lower())
    for e in cv.get("experience", []):
        for k in e.get("key_skills", []):
            s.add(k.lower())
    return s

def skill_match(required, cand):
    matched, missing = [], []
    for req in required:
        r = req.lower()
        (matched if any(r in c or c in r for c in cand) else missing).append(req)
    score = len(matched) / len(required) if required else 1.0
    return score, matched, missing

def parse_ym(s):
    if not s: return None
    p = s.split("-")
    try:
        return int(p[0]) * 12 + (int(p[1]) if len(p) > 1 else 1)
    except Exception:
        return None

def total_years(cv):
    starts, ends = [], []
    for e in cv.get("experience", []):
        st = parse_ym(e.get("start_date", ""))
        en = parse_ym(e.get("end_date", ""))
        if en is None and e.get("is_current"): en = TODAY_YM
        if st is not None: starts.append(st)
        if en is not None: ends.append(en)
    if not starts or not ends: return None
    return round((max(ends) - min(starts)) / 12.0, 1)

def edu_ok(required_level, cv):
    rl = required_level.lower()
    for ed in cv.get("education", []):
        if rl in (ed.get("degree", "") + " " + ed.get("field_of_study", "")).lower():
            return True
    return False

def semantic_score(job_text, cv_id, topk=3):
    res  = col.query(query_embeddings=[embed_query(job_text)], n_results=topk, where={"cv_id": cv_id})
    sims = [1 - d for d in res["distances"][0]]
    return sum(sims) / len(sims) if sims else 0.0

# %%
# ── 2) Skor hybrid + ranking ──────────────────────────────────────────
WEIGHTS = {"skills": 0.40, "semantic": 0.35, "years": 0.15, "education": 0.10}

def score_cv(job, cv_id, cv):
    cand = candidate_skills(cv)
    sk, matched, missing = skill_match(job.get("required_skills", []), cand)
    sem = semantic_score(job.get("description", ""), cv_id)
    yrs = total_years(cv)
    comps = {"skills": sk, "semantic": sem}
    if job.get("min_years_experience"):
        comps["years"] = None if yrs is None else min(yrs / job["min_years_experience"], 1.0)
    if job.get("required_education"):
        comps["education"] = 1.0 if edu_ok(job["required_education"], cv) else 0.0
    tw    = sum(WEIGHTS[k] for k in comps if comps[k] is not None)
    final = sum(WEIGHTS[k] * comps[k] for k in comps if comps[k] is not None) / tw
    return {"name": cv.get("personal_info", {}).get("name", cv_id),
            "final": final, "skills": sk, "semantic": sem, "years": yrs,
            "matched": matched, "missing": missing}

def rank_candidates(job):
    rows = sorted((score_cv(job, c, cv) for c, cv in CVS.items()),
                  key=lambda r: r["final"], reverse=True)
    print("=" * 72)
    print(f"JOB: {job['title']}  |  wajib: {', '.join(job.get('required_skills', []))}")
    if job.get("min_years_experience"): print(f"     min pengalaman: {job['min_years_experience']} th")
    if job.get("required_education"):   print(f"     pendidikan    : {job['required_education']}")
    print("=" * 72)
    for i, r in enumerate(rows, 1):
        yrs = f"{r['years']} th" if r["years"] is not None else "? (tgl kosong)"
        print(f"#{i}  {r['name']}  ——  SKOR {r['final'] * 100:.0f}/100")
        print(f"    skills {r['skills']*100:3.0f}%  |  semantic {r['semantic']*100:3.0f}%  |  pengalaman {yrs}")
        print(f"    cocok : {', '.join(r['matched']) or '-'}")
        print(f"    kurang: {', '.join(r['missing']) or '-'}")
    return rows

# %%
# ── 3) Definisikan JOB DESC + jalankan ranking ────────────────────────
JOB = {
    "title": "Senior Backend Engineer",
    "required_skills": ["Java", "Spring Boot", "Microservices", "PostgreSQL", "REST API", "Docker"],
    "min_years_experience": 5,
    "required_education": "",
    "required_certifications": [],
    "description": (
        "Merancang dan membangun microservices yang scalable, REST API berperforma tinggi, "
        "optimasi database PostgreSQL, CI/CD, dan arsitektur backend untuk sistem enterprise."
    ),
}
rank_candidates(JOB)
# Out:
# ========================================================================
# JOB: Senior Backend Engineer  |  wajib: Java, Spring Boot, Microservices, PostgreSQL, REST API, Docker
#      min pengalaman: 5 th
# ========================================================================
# #1  RIZA ALAMSYA  ——  SKOR 74/100
#     skills  83%  |  semantic  64%  |  pengalaman ? (tgl kosong)
#     cocok : Java, Spring Boot, Microservices, PostgreSQL, Docker
#     kurang: REST API
# #2  Khor Kai Xian  ——  SKOR 72/100
#     skills 100%  |  semantic  40%  |  pengalaman ? (tgl kosong)
#     cocok : Java, Spring Boot, Microservices, PostgreSQL, REST API, Docker
#     kurang: -
# #3  Lai Kah Xing (Wilson)  ——  SKOR 51/100
#     skills  50%  |  semantic  52%  |  pengalaman ? (tgl kosong)
#     cocok : Java, Spring Boot, PostgreSQL
#     kurang: Microservices, REST API, Docker
# #4  AHMAD MU’AZ NABIL BIN MOHAMAD NOOR ZAWAWI  ——  SKOR 49/100
#     skills  50%  |  semantic  47%  |  pengalaman ? (tgl kosong)
#     cocok : Java, PostgreSQL, Docker
#     kurang: Spring Boot, Microservices, REST API
# #5  WAN MUHAMMAD ALIF FIRDAUS  ——  SKOR 47/100
#     skills  50%  |  semantic  43%  |  pengalaman ? (tgl kosong)
#     cocok : Java, PostgreSQL, Docker
#     kurang: Spring Boot, Microservices, REST API
# #6  Resume Mohamad Hafiz Without Phone  ——  SKOR 44/100
#     skills  17%  |  semantic  52%  |  pengalaman 6.4 th
#     cocok : Java
#     kurang: Spring Boot, Microservices, PostgreSQL, REST API, Docker
# #7  Resume Hadri  ——  SKOR 38/100
#     skills  33%  |  semantic  43%  |  pengalaman ? (tgl kosong)
#     cocok : Java, REST API
#     kurang: Spring Boot, Microservices, PostgreSQL, Docker
# #8  AKMAL MUSTAQIM  ——  SKOR 36/100
#     skills  17%  |  semantic  58%  |  pengalaman 1.9 th
#     cocok : Java
#     kurang: Spring Boot, Microservices, PostgreSQL, REST API, Docker
# #9  Danial Irfan Zakaria  ——  SKOR 35/100
#     skills   0%  |  semantic  50%  |  pengalaman 4.7 th
#     cocok : -
#     kurang: Java, Spring Boot, Microservices, PostgreSQL, REST API, Docker
# #10  ILLY ATHIRAH BINTI SHAHROL NIZAM  ——  SKOR 33/100
#     skills  17%  |  semantic  52%  |  pengalaman ? (tgl kosong)
#     cocok : Java
#     kurang: Spring Boot, Microservices, PostgreSQL, REST API, Docker
# #11  Akmal Mustaqim resume DECEMBER 2025  ——  SKOR 32/100
#     skills  17%  |  semantic  50%  |  pengalaman ? (tgl kosong)
#     cocok : Java
#     kurang: Spring Boot, Microservices, PostgreSQL, REST API, Docker
# [{'name': 'RIZA ALAMSYA',
#   'final': 0.7423166937298245,
#   'skills': 0.8333333333333334,
#   'semantic': 0.6382976770401001,
#   'years': None,
#   'matched': ['Java', 'Spring Boot', 'Microservices', 'PostgreSQL', 'Docker'],
#   'missing': ['REST API']},
#  {'name': 'Khor Kai Xian',
#   'final': 0.7215382787916397,
#   'skills': 1.0,
#   'semantic': 0.4032963116963704,
#   'years': None,
#   'matched': ['Java',
#    'Spring Boot',
#    'Microservices',
#    'PostgreSQL',
#    'REST API',
#    'Docker'],
#   'missing': []},
#  {'name': 'Lai Kah Xing (Wilson)',
#   'final': 0.5111122833357916,
#   'skills': 0.5,
#   'semantic': 0.5238120357195536,
#   'years': None,
#   'matched': ['Java', 'Spring Boot', 'PostgreSQL'],
#   'missing': ['Microservices', 'REST API', 'Docker']},
#  {'name': 'AHMAD MU’AZ NABIL BIN MOHAMAD NOOR ZAWAWI',
#   'final': 0.4861084474457635,
#   'skills': 0.5,
#   'semantic': 0.47023238738377887,
#   'years': None,
#   'matched': ['Java', 'PostgreSQL', 'Docker'],
#   'missing': ['Spring Boot', 'Microservices', 'REST API']},
#  {'name': 'WAN MUHAMMAD ALIF FIRDAUS',
#   'final': 0.46652773486243354,
#   'skills': 0.5,
#   'semantic': 0.4282737175623576,
#   'years': None,
#   'matched': ['Java', 'PostgreSQL', 'Docker'],
#   'missing': ['Spring Boot', 'Microservices', 'REST API']},
#  {'name': 'Resume Mohamad Hafiz Without Phone',
#   'final': 0.44335811336835224,
#   'skills': 0.16666666666666666,
#   'semantic': 0.5210161010424296,
#   'years': 6.4,
#   'matched': ['Java'],
#   'missing': ['Spring Boot',
#    'Microservices',
#    'PostgreSQL',
#    'REST API',
#    'Docker']},
#  {'name': 'Resume Hadri',
#   'final': 0.37696566449271307,
#   'skills': 0.3333333333333333,
#   'semantic': 0.4268311858177185,
#   'years': None,
#   'matched': ['Java', 'REST API'],
#   'missing': ['Spring Boot', 'Microservices', 'PostgreSQL', 'Docker']},
#  {'name': 'AKMAL MUSTAQIM',
#   'final': 0.3613628002449318,
#   'skills': 0.16666666666666666,
#   'semantic': 0.5758852958679199,
#   'years': 1.9,
#   'matched': ['Java'],
#   'missing': ['Spring Boot',
#    'Microservices',
#    'PostgreSQL',
#    'REST API',
#    'Docker']},
#  {'name': 'Danial Irfan Zakaria',
#   'final': 0.3520667280974211,
#   'skills': 0.0,
#   'semantic': 0.5024573008219401,
#   'years': 4.7,
#   'matched': [],
#   'missing': ['Java',
#    'Spring Boot',
#    'Microservices',
#    'PostgreSQL',
#    'REST API',
#    'Docker']},
#  {'name': 'ILLY ATHIRAH BINTI SHAHROL NIZAM',
#   'final': 0.3321820629967583,
#   'skills': 0.16666666666666666,
#   'semantic': 0.5213425159454346,
#   'years': None,
#   'matched': ['Java'],
#   'missing': ['Spring Boot',
#    'Microservices',
#    'PostgreSQL',
#    'REST API',
#    'Docker']},
#  {'name': 'Akmal Mustaqim resume DECEMBER 2025',
#   'final': 0.3205925954712761,
#   'skills': 0.16666666666666666,
#   'semantic': 0.4965079426765442,
#   'years': None,
#   'matched': ['Java'],
#   'missing': ['Spring Boot',
#    'Microservices',
#    'PostgreSQL',
#    'REST API',
#    'Docker']}]

# %%
# ── 4) LLM REASONING via MiMo ─────────────────────────────────────────
SYSTEM_INSTRUCTION = (
    "Tugasmu menjelaskan alasan skor kecocokan kandidat terhadap lowongan. "
    "WAJIB hanya memakai fakta di bagian DATA. DILARANG KERAS mengarang skill, perusahaan, "
    "proyek, angka, atau klaim yang tidak ada di DATA.\n"
    "ATURAN KETAT:\n"
    "- KEKUATAN: sebut skill dari SKILL COCOK + pengalaman nyata dari RIWAYAT.\n"
    "- KEKURANGAN: HANYA boleh menyebut item yang tertulis di SKILL KURANG, dan/atau jika "
    "MEMENUHI MIN PENGALAMAN = TIDAK.\n"
    "- PENGALAMAN: pakai nilai field 'MEMENUHI MIN PENGALAMAN' APA ADANYA.\n"
    "- Jika SKILL KURANG '-' dan MEMENUHI MIN PENGALAMAN = YA: nyatakan semua syarat terpenuhi.\n"
    "Jawab 2-3 kalimat Bahasa Indonesia, ringkas."
)

def _exp_verdict(years, min_years):
    if not min_years: return "tidak ada syarat minimal"
    if years is None: return f"tidak diketahui (tahun tidak tercantum; minimal {min_years} th)"
    if years >= min_years: return f"YA ({years} th >= {min_years} th)"
    return f"TIDAK ({years} th < {min_years} th)"

def explain_candidate(result, cv, job):
    riwayat = "\n".join(
        f'- {e.get("role","")} @ {e.get("company","")}: {e.get("summary","")}'
        for e in cv.get("experience", [])
    ) or "- (tidak ada)"
    yrs     = f'{result["years"]} th' if result["years"] is not None else "tidak diketahui"
    verdict = _exp_verdict(result["years"], job.get("min_years_experience"))
    data = (
        f'KANDIDAT: {result["name"]}\n'
        f'SKOR: {round(result["final"]*100)}/100\n'
        f'SKILL COCOK: {", ".join(result["matched"]) or "-"}\n'
        f'SKILL KURANG: {", ".join(result["missing"]) or "-"}\n'
        f'PENGALAMAN: {yrs}\n'
        f'MEMENUHI MIN PENGALAMAN: {verdict}\n'
        f'RINGKASAN CV: {cv.get("summary","")}\n'
        f'RIWAYAT KERJA:\n{riwayat}'
    )
    prompt = (
        f'LOWONGAN: {job["title"]} | skill: {", ".join(job.get("required_skills", []))}'  
        f' | min: {job.get("min_years_experience", "-")} th\n\nDATA:\n{data}'
    )
    resp = client.chat.completions.create(
        model=LLM_MODEL,
        messages=[
            {"role": "system", "content": SYSTEM_INSTRUCTION},
            {"role": "user",   "content": prompt},
        ],
        temperature=0,
    )
    return resp.choices[0].message.content.strip()

_rows = sorted(
    ({**score_cv(JOB, cid, cv), "cv_id": cid} for cid, cv in CVS.items()),
    key=lambda r: r["final"], reverse=True,
)
print("===== ALASAN PER KANDIDAT (MiMo, grounded ke fakta) =====")
for i, r in enumerate(_rows, 1):
    reason = explain_candidate(r, CVS[r["cv_id"]], JOB)
    print(f'\n#{i}  {r["name"]}  —  {round(r["final"]*100)}/100')
    print(f'    {reason}')
# Out:
# ===== ALASAN PER KANDIDAT (MiMo, grounded ke fakta) =====
#
# #1  RIZA ALAMSYA  —  74/100
#     Skor kecocokan Riza Alamsya adalah **74/100**.
#
# **Kekuatan:** Kandidat memiliki 5 dari 6 skill yang dibutuhkan, yaitu Java, Spring Boot, Microservices, PostgreSQL, dan Docker, serta memiliki pengalaman kerja di beberapa perusahaan seperti CMG (Malaysia), Bank Danamon, dan Collega by Telkom Indonesia.
#
# **Kelebihan:** Kandidat belum memiliki skill REST API yang dibutuhkan, dan pengalaman kerjanya tidak terdeteksi secara spesifik sehingga tidak dapat dipastikan memenuhi syarat minimal 5 tahun.
#
# #2  Khor Kai Xian  —  72/100
#     Kandidat memiliki semua skill yang dibutuhkan lowongan: Java, Spring Boot, Microservices, PostgreSQL, REST API, dan Docker. Namun, pengalaman kerjanya tidak tercantum dalam data, sehingga belum bisa dipastikan apakah memenuhi minimal 5 tahun. Skor 72/100 ini terkendala pada kriteria pengalaman yang tidak diketahui.
#
# #3  Lai Kah Xing (Wilson)  —  51/100
#     **Analisis Skor Kecocokan:**
#
# Kandidat menunjukkan kekuatan pada skill Java, Spring Boot, dan PostgreSQL yang merupakan bagian dari stack lowongan, dengan pengalaman 5 tahun di backend development. Namun, kandidat belum memiliki keahlian pada Microservices, REST API, dan Docker yang dibutuhkan. Selain itu, pemenuhan syarat pengalaman minimal 5 tahun tidak dapat dipastikan karena tahun tidak tercantum dalam data.
#
# #4  AHMAD MU’AZ NABIL BIN MOHAMAD NOOR ZAWAWI  —  49/100
#     **Skor 49/100** karena kandidat hanya memiliki 3 dari 6 skill yang dibutuhkan, yaitu **Java, PostgreSQL, dan Docker**.
#
# **Kelemahan utama:** Kandidat belum menguasai **Spring Boot, Microservices, dan REST API** yang merupakan komponen inti backend di lowongan ini. Selain itu, **pengalaman kerja tidak diketahui** (tidak ada riwayat kerja tercantum dan tahun tidak tercantum), sehingga tidak dapat dipastikan apakah memenuhi syarat minimal 5 tahun pengalaman. Dari ringkasan CV, kandidat terlihat fresh graduate yang sedang mencari posisi internship, bukan level senior.
#
# #5  WAN MUHAMMAD ALIF FIRDAUS  —  47/100
#     Skor kecocokan kandidat adalah 47/100. Kekuatan kandidat adalah memiliki skill Java, PostgreSQL, dan Docker yang sesuai dengan kebutuhan lowongan. Kekurangan kandidat adalah tidak memiliki skill Spring Boot, Microservices, dan REST API, serta pengalaman kerjanya tidak diketahui sehingga tidak dapat dipastikan apakah memenuhi syarat minimal 5 tahun.
#
# #6  Resume Mohamad Hafiz Without Phone  —  44/100
#     Skor kecocokan kandidat adalah 44/100 karena memiliki skill Java yang sesuai dengan lowongan dan pengalaman kerja 6,4 tahun yang memenuhi syarat minimum 5 tahun. Kelemahannya adalah tidak memiliki skill Spring Boot, Microservices, PostgreSQL, REST API, dan Docker yang dibutuhkan, meskipun pengalamannya mencukupi.
#
# #7  Resume Hadri  —  38/100
#     Skor kecocokan rendah (38/100) karena kandidat hanya memiliki 2 skill yang sesuai, yaitu Java dan REST API, namun kekurangan skill kritis seperti Spring Boot, Microservices, PostgreSQL, dan Docker. Tidak ada riwayat kerja yang tercantum, sehingga pengalaman tidak diketahui dan tidak dapat dipastikan apakah memenuhi minimal 5 tahun. Kekurangan utama adalah absennya kemampuan dalam framework dan teknologi wajib untuk peran backend senior ini.
#
# #8  AKMAL MUSTAQIM  —  36/100
#     Skor kecocokan rendah karena kandidat hanya memiliki skill Java yang sesuai dengan kebutuhan lowongan, namun tidak memiliki skill Spring Boot, Microservices, PostgreSQL, REST API, dan Docker yang diperlukan. Pengalaman kandidat 1.9 tahun belum memenuhi syarat minimum 5 tahun, sehingga dianggap tidak memenuhi kualifikasi untuk posisi Senior Backend Engineer.
#
# #9  Danial Irfan Zakaria  —  35/100
#     Kandidat tidak memiliki satupun skill yang dibutuhkan lowongan (Java, Spring Boot, Microservices, PostgreSQL, REST API, Docker). Selain itu, pengalaman kerja kandidat 4,7 tahun belum memenuhi syarat minimal 5 tahun. Kombinasi ketiadaan skill yang sesuai dan pengalaman yang kurang dari batas minimum menghasilkan skor kecocokan yang rendah, yaitu 35/100.
#
# #10  ILLY ATHIRAH BINTI SHAHROL NIZAM  —  33/100
#     Kandidat memiliki kecocokan rendah (33/100) karena hanya menguasai Java dari keenam skill yang dibutuhkan. Ia belum memiliki skill utama seperti Spring Boot, Microservices, PostgreSQL, REST API, dan Docker. Selain itu, pengalaman kerjanya tidak diketahui dari data yang tersedia.
#
# #11  Akmal Mustaqim resume DECEMBER 2025  —  32/100
#     **Penjelasan Skor Kecocokan: 32/100**
#
# Kandidat hanya memiliki kecocokan pada 1 dari 6 skill yang dibutuhkan, yaitu **Java**. Kandidat **kurang 5 skill** lainnya: Spring Boot, Microservices, PostgreSQL, REST API, dan Docker. Selain itu, **tidak ada riwayat kerja** yang tercantum dalam CV dan pengalaman minimal 5 tahun **belum terpenuhi (tidak diketahui)**, sehingga skor keseluruhan rendah.
